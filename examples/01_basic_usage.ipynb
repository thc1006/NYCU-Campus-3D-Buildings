# %% [markdown]
# # Google Colab Setup
#
# **Note**: If running on Google Colab, run the cell below to download data first.
#
# **註**: 如在 Google Colab 執行，請先執行下方 cell 下載資料。

# %%
# Google Colab: Download dataset
# 下載資料集（僅 Colab 需要）
import os

if 'COLAB_GPU' in os.environ or not os.path.exists('../data'):
    print('Downloading dataset from GitHub...')
    print('下載資料集...')
    
    # Clone repository
    # !git clone --depth 1 https://github.com/thc1006/NYCU-Campus-3D-Buildings.git
    
    # Change to repository directory
    os.chdir('NYCU-Campus-3D-Buildings/examples')
    
    print('Done! / 完成！')
else:
    print('Running locally / 本地執行')

# %% [markdown]
# # NQSD 範例 1：基礎使用本範例示範如何：- 讀取 GeoJSON 資料- 基本資料探索- 過濾特定校區建築- 簡單統計分析**資料來源**：- NLSC 3D Building Data- OpenStreetMap (© OSM contributors)

# %%
# 匯入必要套件import pandas as pdimport geopandas as gpdimport matplotlib.pyplot as plt# 設定中文字型（避免亂碼）# Font setup for Chinese characters# Colab uses different fonts than Windowsimport matplotlib.font_manager as fmplt.rcParams['font.sans-serif'] = ['DejaVu Sans', 'Arial Unicode MS', 'sans-serif']plt.rcParams['axes.unicode_minus'] = Falseprint("OK 套件載入成功")

# %% [markdown]
# ## 1. 讀取資料

# %%
# 讀取合併資料集（完整版）# 如果記憶體不足，可以使用 sample_data/sample_buildings.geojsonbuildings = gpd.read_file('../data/output/latest/buildings_merged.geojson')print(f"OK 成功讀取 {len(buildings)} 筆建築資料")print(f"資料大小：{buildings.shape}")

# %% [markdown]
# ## 2. 資料探索

# %%
# 查看前 5 筆資料buildings.head()

# %%
# 查看欄位資訊buildings.info()

# %%
# 查看數值欄位統計buildings.describe()

# %% [markdown]
# ## 3. 過濾光復校區有名稱的建築

# %%
# 過濾有名稱的建築named_buildings = buildings[buildings['name'].notna()].copy()print(f"有名稱的建築：{len(named_buildings)} 筆")print(f"\n前 10 棟建築：")print(named_buildings[['name', 'name:en', 'nlsc_BUILD_H']].head(10))

# %% [markdown]
# ## 4. 簡單統計

# %%
# 建築高度統計print("建築高度統計：")print(f"平均高度：{buildings['nlsc_BUILD_H'].mean():.2f} 公尺")print(f"最高建築：{buildings['nlsc_BUILD_H'].max():.2f} 公尺")print(f"最矮建築：{buildings['nlsc_BUILD_H'].min():.2f} 公尺")# 找出最高的 10 棟建築print("\n最高的 10 棟建築：")top_10 = named_buildings.nlargest(10, 'nlsc_BUILD_H')[['name', 'nlsc_BUILD_H']]print(top_10)

# %%
# 建築高度分佈直方圖plt.figure(figsize=(10, 6))plt.hist(buildings['nlsc_BUILD_H'], bins=50, edgecolor='black')plt.xlabel('建築高度（公尺）')plt.ylabel('建築數量')plt.title('NYCU 建築高度分佈')plt.grid(True, alpha=0.3)plt.show()

# %% [markdown]
# ## 5. 匯出資料

# %%
# 匯出有名稱的建築為 CSVoutput_file = 'outputs/named_buildings.csv'named_buildings[['name', 'name:en', 'nlsc_BUILD_H', 'nlsc_BUILD_STR']].to_csv(    output_file,     index=False,     encoding='utf-8-sig'  # Excel 相容)print(f"OK 已匯出至 {output_file}")

# %% [markdown]
# ## 總結本範例示範了：- [OK] 讀取 GeoJSON 資料- [OK] 基本資料探索（head, info, describe）- [OK] 過濾資料（有名稱的建築）- [OK] 簡單統計（平均高度、最高建築）- [OK] 視覺化（直方圖）- [OK] 匯出 CSV下一步：- 查看 `02_data_analysis.ipynb` 進行更深入的資料分析- 查看 `03_visualization.ipynb` 學習地圖視覺化
